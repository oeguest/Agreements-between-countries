# %%
import pyreadr

# %%
result = pyreadr.read_r('ICBe_V1.1_crises_markdown.Rds')

df1 = result[None] # extract the pandas data frame for the only object available
df1
# Out:
#      crisno                    crisis_text  n_sentence_number_int_aligned  \
# 0       1.0            RUSSIAN CIVIL WAR I                             12
# 1       2.0               COSTA RICAN COUP                             20
# 2       3.0           RUSSIAN CIVIL WAR II                              9
# 3       4.0            BALTIC INDEPENDENCE                             33
# 4       5.0                        TESCHEN                             22
# ..      ...                            ...                            ...
# 470   471.0                Crimea-Donbass1                             83
# 471   472.0               Chinese Oil Rig1                             41
# 472   473.0  India-Pakistan Border Firing1                             30
# 473   475.0              Korean Land Mine1                             33
# 474   476.0    Turkey-Russia Jet Incident1                             82
#
#      n_events  yrtrig  yrterm  coders_expert  coders_novice  \
# ...

# %%
result = pyreadr.read_r('ICBe_V1.1_events_agreed_long.Rds')

df2 = result[None] # extract the pandas data frame for the only object available
df2
# Out:
#         crisno                  crisis_text  sentence_number_int_aligned  \
# 0          1.0          RUSSIAN CIVIL WAR I                            2
# 1          1.0          RUSSIAN CIVIL WAR I                            2
# 2          1.0          RUSSIAN CIVIL WAR I                            2
# 3          1.0          RUSSIAN CIVIL WAR I                            2
# 4          1.0          RUSSIAN CIVIL WAR I                            2
# ...        ...                          ...                          ...
# 313371   476.0  Turkey-Russia Jet Incident1                           82
# 313372   476.0  Turkey-Russia Jet Incident1                           82
# 313373   476.0  Turkey-Russia Jet Incident1                           82
# 313374   476.0  Turkey-Russia Jet Incident1                           82
# 313375   476.0  Turkey-Russia Jet Incident1                           82
#
#                                        sentence_span_text  \
# ...

# %%
result = pyreadr.read_r('ICBe_V1.1_long_clean.Rds')

df3 = result[None] # extract the pandas data frame for the only object available
df3
# Out:
#                    varname                     value  event_number_int  \
# 0                   crisis   abortive coup-indonesia               0.0
# 1                   crisno                       164               0.0
# 2       icb_survey_version                       1.2               0.0
# 3               lastviewed  mon may  2 14:07:17 2016               0.0
# 4                  section                background               0.0
# ...                    ...                       ...               ...
# 993735  icb_survey_version                       1.3               0.0
# 993736          lastviewed  sat jul 16 18:14:42 2016               0.0
# 993737             section                      text               0.0
# 993738     sentence_events                background               0.0
# 993739      sentencenumber                        17               0.0
#
#                    input_crisis  crisno email_crc32 email_id status  expert  \
# ...

# %%
result = pyreadr.read_r('ICBe_V1.1_events_agreed_markdown.Rds')

df4 = result[None] # extract the pandas data frame for the only object available
df4
# Out:
#        crisno  sentence_number_int_aligned  \
# 0         1.0                            2
# 1         1.0                            2
# 2         1.0                            6
# 3         1.0                            8
# 4         1.0                            8
# ...       ...                          ...
# 15137   476.0                           79
# 15138   476.0                           80
# 15139   476.0                           81
# 15140   476.0                           82
# 15141   476.0                           82
#
#                                       sentence_span_text  \
# 0      The Communist regime, which had attained power...
# 1      The Communist regime, which had attained power...
# 2      Serious clashes between them ensued triggering...
# 3      However, the lack of sustained military suppor...
# 4      However, the lack of sustained military suppor...
# ...                                                  ...
# ...

# %%
result = pyreadr.read_r('icb_corpus_V1.0_May_16_2022.Rds')

df5 = result[None] # extract the pandas data frame for the only object available
df5
# Out:
#      crisno                      crisis_title  \
# 0       1.0     CRISNO 1  RUSSIAN CIVIL WAR I
# 1       2.0        CRISNO 2  COSTA RICAN COUP
# 2       3.0    CRISNO 3  RUSSIAN CIVIL WAR II
# 3       4.0     CRISNO 4  BALTIC INDEPENDENCE
# 4       5.0                 CRISNO 5  TESCHEN
# ..      ...                               ...
# 481   483.0                Kisangani Conflict
# 482   484.0            Serbian Train Incident
# 483   485.0         Shrine Lal Shahbaz Attack
# 484   486.0  Syria Chemical Weapons Crisis II
# 485   487.0           North Korea Nuclear VII
#
#                                                   text  \
# 0    Bolshevik Russia, precursor to the Soviet Unio...
# 1    A two-stage crisis between Nicaragua and Costa...
# 2    For much of the period of Russian Civil War I ...
# 3    An international crisis between Russia and the...
# 4    Czechoslovakia and Poland were enmeshed in a c...
# ..                                                 ...
# ...
