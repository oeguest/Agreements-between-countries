# %% [markdown]
# Out of the 475 international crises in the dataset, 234 had an agreement being signed as a consequence; 6 had allow inspections.
#
# Source: https://www.crisisevents.org/

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

import pyreadr

result = pyreadr.read_r('ICBe_V1.1_crises_markdown.Rds')
df = result[None]

# %%
df = df.loc[:, ['crisno', 'crisis_text', 'yrtrig','yrterm','act']]
df
# Out:
#      crisno                    crisis_text  yrtrig  yrterm  \
# 0       1.0            RUSSIAN CIVIL WAR I  1918.0  1920.0
# 1       2.0               COSTA RICAN COUP  1918.0  1919.0
# 2       3.0           RUSSIAN CIVIL WAR II  1918.0  1919.0
# 3       4.0            BALTIC INDEPENDENCE  1918.0  1920.0
# 4       5.0                        TESCHEN  1919.0  1920.0
# ..      ...                            ...     ...     ...
# 470   471.0                Crimea-Donbass1  2014.0  2015.0
# 471   472.0               Chinese Oil Rig1  2014.0  2014.0
# 472   473.0  India-Pakistan Border Firing1  2014.0  2014.0
# 473   475.0              Korean Land Mine1  2015.0  2015.0
# 474   476.0    Turkey-Russia Jet Incident1  2015.0  2016.0
#
# ...

# %%
df[df['act'].str.contains("sign")]
# Out:
#      crisno                  crisis_text  yrtrig  yrterm  \
# 3       4.0          BALTIC INDEPENDENCE  1918.0  1920.0
# 4       5.0                      TESCHEN  1919.0  1920.0
# 5       6.0                HUNGARIAN WAR  1919.0  1919.0
# 6       7.0                       SMYRNA  1919.0  1919.0
# 7       8.0             THIRD AFGHAN WAR  1919.0  1919.0
# ..      ...                          ...     ...     ...
# 465   466.0           Sudan-South Sudan1  2011.0  2012.0
# 466   467.0           Scarborough Shoal1  2012.0  2012.0
# 468   469.0       North Korea Nuclear V1  2013.0  2013.0
# 470   471.0              Crimea-Donbass1  2014.0  2015.0
# 474   476.0  Turkey-Russia Jet Incident1  2015.0  2016.0
#
# ...

# %%
df[df['act'].str.contains("inspections")]
# Out:
#      crisno                     crisis_text  yrtrig  yrterm  \
# 407   408.0          NORTH KOREA NUCLEAR I1  1993.0  1994.0
# 428   429.0  UNSCOM II OPERATION DESERT FOX  1998.0  1998.0
# 439   440.0              IRAQ REGIME CHANGE  2002.0  2003.0
# 449   450.0         NORTH KOREA NUCLEAR III  2006.0  2007.0
# 466   467.0              Scarborough Shoal1  2012.0  2012.0
# 469   470.0         Syria Chemical Weapons1  2013.0  2013.0
#
# ...
